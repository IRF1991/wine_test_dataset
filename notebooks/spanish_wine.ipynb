# %%
# Importo las librerías que usaré en el proyecto

import pandas as pd
import numpy as np

# %%
# Cargo el dataset que voy a utilizar (./datasets/akc-data-latest.csv)

df = pd.read_csv('../datasets/wines_SPA.csv')

# %%
# Muestro una fila aleatoria del dataset para ver las columnas y su contenido

df.sample(1)
# Out:
#         winery                wine  year  rating  num_reviews country region  \
# 2360  Campillo  Gran Reserva Rioja  2012     4.2          410  Espana  Rioja
#
#       price       type  body  acidity
# 2360  22.99  Rioja Red   4.0      3.0

# %%
# Muestro el tipo de dato de cada columna y los valores únicos para identificar variables

print("Tipos de datos por columna:")
print(df.dtypes)
print("\nValores únicos por columna:")
for col in df.columns:
    print(f"{col}: {df[col].nunique()}")
# Out:
# Tipos de datos por columna:
# winery          object
# wine            object
# year            object
# rating         float64
# num_reviews      int64
# country         object
# region          object
# price          float64
# type            object
# body           float64
# acidity        float64
# dtype: object
#
# Valores únicos por columna:
# winery: 480
# wine: 847
# year: 71
# rating: 8
# num_reviews: 817
# country: 1
# region: 76
# price: 1292
# type: 21
# body: 4
# acidity: 3

# %%
# Reviso las estadísticas descriptivas del dataset

df.describe()
# Out:
#             rating   num_reviews        price         body      acidity
# count  7500.000000   7500.000000  7500.000000  6331.000000  6331.000000
# mean      4.254933    451.109067    60.095822     4.158427     2.946612
# std       0.118029    723.001856   150.356676     0.583352     0.248202
# min       4.200000     25.000000     4.990000     2.000000     1.000000
# 25%       4.200000    389.000000    18.900000     4.000000     3.000000
# 50%       4.200000    404.000000    28.530000     4.000000     3.000000
# 75%       4.200000    415.000000    51.350000     5.000000     3.000000
# max       4.900000  32624.000000  3119.080000     5.000000     3.000000

# %%
# Reviso los valores nulos por columna

print(df.isnull().sum())
# Out:
# winery            0
# wine              0
# year              2
# rating            0
# num_reviews       0
# country           0
# region            0
# price             0
# type            545
# body           1169
# acidity        1169
# dtype: int64

# %%
# Compruebo el número de filas duplicadas 

print("Duplicados:", df.duplicated().sum())
# Out:
# Duplicados: 5452

# %%
# 8. Elimio las filas duplicadas

df = df.drop_duplicates()
print("Duplicados:", df.duplicated().sum())
# Out:
# Duplicados: 0

# %%
# Miro los valores únicos de algunas columnas importantes para el análisis por si hubiese outliers destacables

print(f"rating: {df["rating"].unique()}")
print(f"price: {df["price"].unique()}")
print(f"body: {df["body"].unique()}")
print(f"acidity: {df["acidity"].unique()}")
# Out:
# rating: [4.9 4.8 4.7 4.6 4.5 4.4 4.3 4.2]
# price: [995.   313.5  324.95 ...  16.76  24.45  31.63]
# body: [ 5.  4.  3. nan  2.]
# acidity: [ 3.  2.  1. nan]

# %%
# Vuelvo a revisar la información y los valores nulos por columna
    # El número de filas se ha reducido de 7500 a 2048 al eliminar duplicados
    
print(df.info())
print(df.isnull().sum())
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 2048 entries, 0 to 6100
# Data columns (total 11 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   winery       2048 non-null   object
#  1   wine         2048 non-null   object
#  2   year         2046 non-null   object
#  3   rating       2048 non-null   float64
#  4   num_reviews  2048 non-null   int64
#  5   country      2048 non-null   object
#  6   region       2048 non-null   object
#  7   price        2048 non-null   float64
#  8   type         1942 non-null   object
#  9   body         1777 non-null   float64
#  10  acidity      1777 non-null   float64
# dtypes: float64(4), int64(1), object(6)
# memory usage: 192.0+ KB
# None
# winery           0
# wine             0
# year             2
# rating           0
# num_reviews      0
# country          0
# region           0
# price            0
# type           106
# body           271
# acidity        271
# dtype: int64

# %%
# Decido revisar los nulos de la columna "year" para saber cómo gestionarlos

df[df["year"].isnull()]
# Out:
#            winery                            wine year  rating  num_reviews  \
# 46   Vega Sicilia  Unico Reserva Especial Edicion  NaN     4.7        12421
# 851      La Unica                  Fourth Edition  NaN     4.4          131
#
#     country            region  price                  type  body  acidity
# 46   Espana  Ribera del Duero  423.5  Ribera Del Duero Red   5.0      3.0
# 851  Espana    Vino de Espana   40.0           Tempranillo   4.0      2.0

# %%
# Mantengo los nulos en "year" y los gestionaré al convertir la columna a numérica

# %%
# Reviso los valores nulos en la columna "type" para decidir cómo gestionarlos
    # Observo un patrón entre los nulos de type, body y acidity
    
df[df["type"].isnull()]
# Out:
#                                 winery  \
# 120                      Finca Moncloa
# 147                    Rafael Palacios
# 156               Gutierrez de la Vega
# 254                Costers del Siurana
# 288             Francisco Garcia Perez
# 303                     Casal de Arman
# 312                 Pago de Larrainzar
# 318                      Finca Moncloa
# 340                    Telmo Rodriguez
# 477                        Emilio Rojo
# 488                    Rafael Palacios
# 576                         Veigamoura
# 610                       Amos Baneres
# 744                    Rafael Palacios
# 756                    Abadia Retuerta
# 757                    Rafael Palacios
# 796                R. Lopez de Heredia
# 801                   Dominio do Bibei
# 839                Bodegas El Paraguas
# 848                      Bodegas Mauro
# 887             Pago de Los Capellanes
# 892                    Abadia Retuerta
# 908                   Bodegas Mas Alta
# 916          Luis A. Rodriguez Vazquez
# 938                        Alta Alella
# 967                      Jorge Ordonez
# 981                        Enric Soler
# 983                          Es Fangar
# 1040                  Bodegas Mas Alta
# 1059                       Enric Soler
# 1066                    Castell Miquel
# 1067                 Barco del Corneta
# 1081                   Castell d'Encus
# 1101              Gutierrez de la Vega
# 1116                    Familia Torres
# 1265                       St. Petroni
# 1268                     Llanos Negros
# 1280                           Avancia
# 1296                   Abadia Retuerta
# 1301                   Abadia Retuerta
# 1313                      Clos Mogador
# 1319                           Godeval
# 1327                   Castell d'Encus
# 1334                  Dominio do Bibei
# 1343                     Jorge Ordonez
# 1382                   Abadia Retuerta
# 1387                     Bodegas Mauro
# 1408                      Vinos Guerra
# 1412                         Scala Dei
# 1425                       St. Petroni
# 1445                     Bodegas Mauro
# 1457                         De Muller
# 1478               Pago de Vallegarcia
# 1489                    Perez Barquero
# 1511                     Llanos Negros
# 1513                       Alta Alella
# 1515                     Bodegas Ochoa
# 1530              Can Rafols dels Caus
# 1534               Dominio del Bendito
# 1543              Can Rafols dels Caus
# 1550                         Scala Dei
# 1564                         Scala Dei
# 1568         Terroir Al Limit Soc. Lda
# 1598                         Scala Dei
# 1604                       Enric Soler
# 1614                 Bodegas Yzaguirre
# 1620                Finca Torremilanos
# 1622                          Pradorey
# 1625                Bodega Aida i Luis
# 1642                          Cervoles
# 1646                 Bodegas San Roman
# 1665                         Atlantida
# 1687                Bodegas Luis Perez
# 1695                           Avancia
# 1697                 Bodegas Frontonio
# 1790           28  Espana    Ribera del Duero   49.00000  NaN   NaN      NaN
# 1799           27  Espana        Gran Canaria   29.75000  NaN   NaN      NaN
# 1807           26  Espana     Castilla y Leon   17.74000  NaN   NaN      NaN
# 1820           25  Espana            Cataluna   56.95000  NaN   NaN      NaN
# 1851         2685  Espana          Valdeorras   19.70000  NaN   NaN      NaN
# 1882         1164  Espana             Penedes    9.95000  NaN   NaN      NaN
# 1891         1058  Espana  Jerez-Xeres-Sherry   11.90000  NaN   NaN      NaN
# 1914          842  Espana             Navarra    5.50000  NaN   NaN      NaN
# 1934          692  Espana             Penedes   11.20000  NaN   NaN      NaN
# 1982          484  Espana              Bierzo   21.95000  NaN   NaN      NaN
# 1995          432  Espana            Alicante   49.95000  NaN   NaN      NaN
# 2011          407  Espana             Ribeiro   11.95000  NaN   NaN      NaN
# 2014          404  Espana            Mallorca   19.90000  NaN   NaN      NaN

# %%
# Al revisar los nulos de la columna "type", observo que todos los registros con "type" nulo también tienen "body" y "acidity" nulos
    
mask = df["type"].isnull()
print((df.loc[mask, ["body", "acidity"]].isnull().all(axis=1)).sum())
print(len(df[mask]))
# Out:
# 106
# 106

# %%
# Me doy cuenta de que la columna "type" mezcla los tipos de vino por uva, denominación de origen y estilo de vino
    # Esto dificulta el análisis, ya que no es consistente

# %%
# Compruebo los valores únicos de body y acidity por tipo de vino antes de eliminar la columna "type"
    # Veo que el valor de body y acidity es igual para cada tipo de vino
    # Por lo tanto, puedo usar esos valores para rellenar body y acidity antes de eliminar la columna "type"
    
print(df.groupby("type")[["body", "acidity"]].nunique())
# Out:
#                       body  acidity
# type
# Albarino                 1        1
# Cabernet Sauvignon       1        1
# Cava                     1        1
# Chardonnay               1        1
# Grenache                 1        1
# Mencia                   1        1
# Monastrell               1        1
# Montsant Red             1        1
# Pedro Ximenez            1        1
# Priorat Red              1        1
# Red                      1        1
# Ribera Del Duero Red     1        1
# Rioja Red                1        1
# Rioja White              1        1
# Sauvignon Blanc          1        1
# Sherry                   1        1
# Sparkling                1        1
# Syrah                    1        1
# Tempranillo              1        1
# Toro Red                 1        1
# Verdejo                  1        1

# %%
# Relleno los nulos de body y acidity usando los valores medios por tipo de vino y elimino la columna "type"

df["body"] = df.groupby("type")["body"].transform(lambda x: x.fillna(x.mean()))
df["acidity"] = df.groupby("type")["acidity"].transform(lambda x: x.fillna(x.mean()))
df = df.drop(columns=["type"])

# %%
df.sample(1)
# Out:
#                winery        wine  year  rating  num_reviews country  \
# 1610  Alvaro Palacios  Finca Dofi  1997     4.3           60  Espana
#
#         region  price  body  acidity
# 1610  Priorato  170.0   4.0      3.0

# %%
# Vuelvo a comprobar los valores nulos tras las transformaciones realizadas

print(df.dtypes)
print("\nValores nulos por columna:")
print(df.isnull().sum())
# Out:
# winery          object
# wine            object
# year            object
# rating         float64
# num_reviews      int64
# country         object
# region          object
# price          float64
# body           float64
# acidity        float64
# dtype: object
#
# Valores nulos por columna:
# winery           0
# wine             0
# year             2
# rating           0
# num_reviews      0
# country          0
# region           0
# price            0
# body           106
# acidity        106
# dtype: int64
